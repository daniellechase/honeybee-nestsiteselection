# %%
# %matplotlib widget
import matplotlib
# Prevent the script's MacOSX backend call from overriding the notebook backend
matplotlib.use = lambda *a, **kw: None
exec(open('honeybee_sim.py').read())
